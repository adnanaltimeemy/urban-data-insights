# %%
# Core libraries
import pandas as pd
import numpy as np

# Visualization (optional)
import matplotlib.pyplot as plt
import seaborn as sns

# ML tools
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Load CSV
df = pd.read_csv("language-codes.csv")

# Preview
df.head()
# Out:
#   alpha2    English
# 0     aa       Afar
# 1     ab  Abkhazian
# 2     ae    Avestan
# 3     af  Afrikaans
# 4     ak       Akan

# %%
print(df.info())
print(df.describe())

# Check missing values
print(df.isnull().sum())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   alpha2   183 non-null    str
#  1   English  183 non-null    str
# dtypes: str(2)
# memory usage: 5.1 KB
# None
#        alpha2 English
# count     183     183
# unique    183     183
# top        aa    Afar
# freq        1       1
# alpha2     0
# English    0
# dtype: int64

# %%
# Copy dataset
data = df.copy()

# Encode categorical features
le_dict = {}

for col in data.columns:
    if data[col].dtype == 'object':
        le = LabelEncoder()
        data[col] = le.fit_transform(data[col])
        le_dict[col] = le

# %%
print(data.columns)
# Out:
# Index(['alpha2', 'English'], dtype='str')

# %%
print(df.head())
# Out:
#   alpha2    English
# 0     aa       Afar
# 1     ab  Abkhazian
# 2     ae    Avestan
# 3     af  Afrikaans
# 4     ak       Akan

# %%
print(type(df))   # should be DataFrame
print(df.columns)
# Out:
# <class 'pandas.DataFrame'>
# Index(['alpha2', 'English'], dtype='str')
