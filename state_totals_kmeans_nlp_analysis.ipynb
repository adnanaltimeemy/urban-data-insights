# %%
# Data handling
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# NLP
from sklearn.feature_extraction.text import TfidfVectorizer

# Dimensionality reduction
from sklearn.decomposition import PCA

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Load CSV
df = pd.read_csv("State Totals Comparisons.csv")

# Preview data
df.head()
# Out:
#              State  Total acquisition cost ($) (2006 - 2014)  \
# 0  Washington D.C.                                  21741478
# 1    West Virginia                                   8970651
# 2         Illinois                                  63856929
# 3    Massachusetts                                  11878712
# 4           Hawaii                                    521054
#
#    Total number of Items  Average price per item  \
# 0                   4736                 4590.68
# 1                  27759                  323.16
# 2                  42253                 1511.30
# 3                   7864                 1510.52
# 4                     18                28947.47
#
#    Total acquisition cost ($ per inhabitant)  \
# 0                                      36.13
# 1                                       4.84
# 2                                       4.98
# 3                                       1.81
# 4                                       0.38
#
#    Total acquisition cost ($ per police agency)  \
# 0                                   10870739.05
# 1                                      25269.44
# 2                                     109908.66
# 3                                      36105.51
# 4                                     130263.60
#
#    Total acquisition cost ($ per inhabitant) (Rank)  \
# 0                                                54
# 1                                                33
# 2                                                34
# 3                                                13
# 4                                                 1
#
#    Total acquisition cost ($ per police agency) (Rank)  \
# 0                                               51.0
# 1                                                8.0
# 2                                               35.0
# 3                                               16.0
# 4                                               40.0
#
#    Police officers (per 1,000 inhabitants)  \
# 0                                     7.17
# 1                                     1.90
# 2                                     2.49
# 3                                     2.45
# 4                                     2.16
#
#    Police officers (per 1,000 inhabitants) (Rank)  ...  \
# 0                                            51.0  ...
# 1                                            17.0  ...
# 2                                            43.0  ...
# 3                                            42.0  ...
# 4                                            30.0  ...
#
#    Police officers killed or assaulted (2012) (per 100 officers) (Rank)  \
# 0                                                1.0
# 1                                                2.0
# 2                                                3.0
# 3                                                4.0
# 4                                                5.0
#
#    Violent Crime Rate (Rank)  Population (2010 Census)  \
# 0                        1.0                   601,723
# 1                       28.0                   1852994
# 2                       18.0                  12830632
# 3                       21.0                   6547629
# 4                       42.0                   1360301
#
#   Police officers (Full-time) (2012)  Number of police agencies  \
# 0                             4315.0                        2.0
# 1                             3528.0                      355.0
# 2                            31893.0                      581.0
# 3                            16046.0                      329.0
# 4                             2942.0                        4.0
#
#    Law Enforcement Felonoiusly Killed  Law Enforcement Officers Assaulted  \
# 0                                   0                                 NaN
# 1                                   3                                 NaN
# 2                                   0                               110.0
# 3                                   1                                57.0
# 4                                   0                                36.0
#
#    Total Law Enforcement Officers Killed or Assaulted (2012)  \
# 0                                                  0
# 1                                                  3
# 2                                                110
# 3                                                 58
# 4                                                 36
#
#    Total Law Enforcement Officers Killed or Assaulted (2012) (per 100 police officers)  \
# 0                                                0.0
# 1                                                0.1
# 2                                                0.3
# 3                                                0.4
# 4                                                1.2
#
#    Violent Crime Rate
# 0              1243.7
# 1               316.3
# 2               414.8
# 3               405.5
# 4               239.2
#
# [5 rows x 21 columns]

# %%
# Info
df.info()

# Summary stats
df.describe()

# Check missing values
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 21 columns):
#  #   Column                                                                               Non-Null Count  Dtype
# ---  ------                                                                               --------------  -----
#  0   State                                                                                54 non-null     str
#  1   Total acquisition cost ($) (2006 - 2014)                                             54 non-null     int64
#  2   Total number of Items                                                                54 non-null     int64
#  3   Average price per item                                                               54 non-null     float64
#  4   Total acquisition cost ($ per inhabitant)                                            54 non-null     float64
#  5   Total acquisition cost ($ per police agency)                                         51 non-null     float64
#  6   Total acquisition cost ($ per inhabitant) (Rank)                                     54 non-null     int64
#  7   Total acquisition cost ($ per police agency) (Rank)                                  51 non-null     float64
#  8   Police officers (per 1,000 inhabitants)                                              51 non-null     float64
#  9   Police officers (per 1,000 inhabitants) (Rank)                                       51 non-null     float64
#  10  2013 acquisition cost ($ per inhabitant) (Rank)                                      51 non-null     float64
#  11  Police officers killed or assaulted (2012) (per 100 officers) (Rank)                 51 non-null     float64
#  12  Violent Crime Rate (Rank)                                                            51 non-null     float64
#  13  Population (2010 Census)                                                             54 non-null     str
#  14  Police officers (Full-time) (2012)                                                   51 non-null     float64
#  15  Number of police agencies                                                            51 non-null     float64
#  16  Law Enforcement Felonoiusly Killed                                                   54 non-null     int64
#  17  Law Enforcement Officers Assaulted                                                   49 non-null     float64
#  18  Total Law Enforcement Officers Killed or Assaulted (2012)                            54 non-null     int64
#  19  Total Law Enforcement Officers Killed or Assaulted (2012) (per 100 police officers)  51 non-null     float64
#  20  Violent Crime Rate                                                                   51 non-null     float64
# dtypes: float64(14), int64(5), str(2)
# memory usage: 9.8 KB
# State                                                                                  0
# Total acquisition cost ($) (2006 - 2014)                                               0
# Total number of Items                                                                  0
# Average price per item                                                                 0
# Total acquisition cost ($ per inhabitant)                                              0
# Total acquisition cost ($ per police agency)                                           3
# Total acquisition cost ($ per inhabitant) (Rank)                                       0
# Total acquisition cost ($ per police agency) (Rank)                                    3
# Police officers (per 1,000 inhabitants)                                                3
# Police officers (per 1,000 inhabitants) (Rank)                                         3
# 2013 acquisition cost ($ per inhabitant) (Rank)                                        3
# Police officers killed or assaulted (2012) (per 100 officers) (Rank)                   3
# Violent Crime Rate (Rank)                                                              3
# Population (2010 Census)                                                               0
# Police officers (Full-time) (2012)                                                     3
# Number of police agencies                                                              3
# Law Enforcement Felonoiusly Killed                                                     0
# Law Enforcement Officers Assaulted                                                     5
# Total Law Enforcement Officers Killed or Assaulted (2012)                              0
# Total Law Enforcement Officers Killed or Assaulted (2012) (per 100 police officers)    3
# Violent Crime Rate                                                                     3
# dtype: int64

# %%
# Fill missing numeric values with mean
numeric_cols = df.select_dtypes(include=np.number).columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())

# Fill missing text values
if 'Notes' in df.columns:
    df['Notes'] = df['Notes'].fillna('')

# %%
features = df[numeric_cols]

# %%
print(df.columns)
# Out:
# Index(['State', 'Total acquisition cost ($) (2006 - 2014)',
#        'Total number of Items', 'Average price per item',
#        'Total acquisition cost ($ per inhabitant)',
#        'Total acquisition cost ($ per police agency)',
#        'Total acquisition cost ($ per inhabitant) (Rank)',
#        'Total acquisition cost ($ per police agency) (Rank)',
#        'Police officers (per 1,000 inhabitants)',
#        'Police officers (per 1,000 inhabitants) (Rank)',
#        '2013 acquisition cost ($ per inhabitant) (Rank)',
#        'Police officers killed or assaulted (2012) (per 100 officers) (Rank)',
#        'Violent Crime Rate (Rank)', 'Population (2010 Census)',
#        'Police officers (Full-time) (2012)', 'Number of police agencies',
#        'Law Enforcement Felonoiusly Killed',
#        'Law Enforcement Officers Assaulted',
#        'Total Law Enforcement Officers Killed or Assaulted (2012)',
#        'Total Law Enforcement Officers Killed or Assaulted (2012) (per 100 police officers)',
#        'Violent Crime Rate'],
#       dtype='str')

# %%
print(df.head())
# Out:
#              State  Total acquisition cost ($) (2006 - 2014)  \
# 0  Washington D.C.                                  21741478
# 1    West Virginia                                   8970651
# 2         Illinois                                  63856929
# 3    Massachusetts                                  11878712
# 4           Hawaii                                    521054
#
#    Total number of Items  Average price per item  \
# 0                   4736                 4590.68
# 1                  27759                  323.16
# 2                  42253                 1511.30
# 3                   7864                 1510.52
# 4                     18                28947.47
#
#    Total acquisition cost ($ per inhabitant)  \
# 0                                      36.13
# 1                                       4.84
# 2                                       4.98
# 3                                       1.81
# 4                                       0.38
#
#    Total acquisition cost ($ per police agency)  \
# 0                                   10870739.05
# 1                                      25269.44
# 2                                     109908.66
# 3                                      36105.51
# 4                                     130263.60
#
#    Total acquisition cost ($ per inhabitant) (Rank)  \
# 0                                                54
# 1                                                33
# 2                                                34
# 3                                                13
# 4                                                 1
#
#    Total acquisition cost ($ per police agency) (Rank)  \
# 0                                               51.0
# 1                                                8.0
# 2                                               35.0
# 3                                               16.0
# 4                                               40.0
#
#    Police officers (per 1,000 inhabitants)  \
# 0                                     7.17
# 1                                     1.90
# 2                                     2.49
# 3                                     2.45
# 4                                     2.16
#
#    Police officers (per 1,000 inhabitants) (Rank)  ...  \
# 0                                            51.0  ...
# 1                                            17.0  ...
# 2                                            43.0  ...
# 3                                            42.0  ...
# 4                                            30.0  ...
#
#    Police officers killed or assaulted (2012) (per 100 officers) (Rank)  \
# 0                                                1.0
# 1                                                2.0
# 2                                                3.0
# 3                                                4.0
# 4                                                5.0
#
#    Violent Crime Rate (Rank)  Population (2010 Census)  \
# 0                        1.0                   601,723
# 1                       28.0                   1852994
# 2                       18.0                  12830632
# 3                       21.0                   6547629
# 4                       42.0                   1360301
#
#   Police officers (Full-time) (2012)  Number of police agencies  \
# 0                             4315.0                        2.0
# 1                             3528.0                      355.0
# 2                            31893.0                      581.0
# 3                            16046.0                      329.0
# 4                             2942.0                        4.0
#
#    Law Enforcement Felonoiusly Killed  Law Enforcement Officers Assaulted  \
# 0                                   0                         1079.612245
# 1                                   3                         1079.612245
# 2                                   0                          110.000000
# 3                                   1                           57.000000
# 4                                   0                           36.000000
#
#    Total Law Enforcement Officers Killed or Assaulted (2012)  \
# 0                                                  0
# 1                                                  3
# 2                                                110
# 3                                                 58
# 4                                                 36
#
#    Total Law Enforcement Officers Killed or Assaulted (2012) (per 100 police officers)  \
# 0                                                0.0
# 1                                                0.1
# 2                                                0.3
# 3                                                0.4
# 4                                                1.2
#
#    Violent Crime Rate
# 0              1243.7
# 1               316.3
# 2               414.8
# 3               405.5
# 4               239.2
#
# [5 rows x 21 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

# Scale numeric features
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns
scaler = StandardScaler()
scaled_features = scaler.fit_transform(df[numerical_columns])

# Handle text if present
if 'Notes' in df.columns:
    vectorizer = TfidfVectorizer()
    text_features = vectorizer.fit_transform(df['Notes'].fillna(''))
    combined_features = np.hstack((scaled_features, text_features.toarray()))
else:
    combined_features = scaled_features
