# %%
import pandas as pd
import numpy as np

# NLP
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Vectorization
from sklearn.feature_extraction.text import TfidfVectorizer

# Clustering
from sklearn.cluster import KMeans

# Visualization
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
df = pd.read_csv("Leaked Files.csv")

# Preview
df.head()
# Out:
#                     Contents        Date                Release Number  \
# 0                       Fury  26/11/2014  The Movie Leak (1st release)
# 1                      Annie  26/11/2014  The Movie Leak (1st release)
# 2                Still Alice  26/11/2014  The Movie Leak (1st release)
# 3                 Mr. Turner  26/11/2014  The Movie Leak (1st release)
# 4  To Write Love on Her Arms  26/11/2014  The Movie Leak (1st release)
#
#   Main Contents of Leak Approximate Size (Mb) Files  \
# 0      Unreleased Movie                  2000     1
# 1      Unreleased Movie                  2000     1
# 2      Unreleased Movie                  2000     1
# 3      Unreleased Movie                  2000     1
# 4      Unreleased Movie                  2000     1
#
#                                               Source
# 0  https://www.riskbasedsecurity.com/2014/12/a-br...
# 1  https://www.riskbasedsecurity.com/2014/12/a-br...
# 2  https://www.riskbasedsecurity.com/2014/12/a-br...
# 3  https://www.riskbasedsecurity.com/2014/12/a-br...
# 4  https://www.riskbasedsecurity.com/2014/12/a-br...

# %%
df.columns
# Out:
# Index(['Contents', 'Date', 'Release Number', 'Main Contents of Leak',
#        'Approximate Size (Mb)', 'Files', 'Source'],
#       dtype='str')

# %%
print(df.columns.tolist())
# Out:
# ['Contents', 'Date', 'Release Number', 'Main Contents of Leak', 'Approximate Size (Mb)', 'Files', 'Source']

# %%
print(df.isnull().sum())
# Out:
# Contents                 0
# Date                     0
# Release Number           0
# Main Contents of Leak    0
# Approximate Size (Mb)    0
# Files                    3
# Source                   0
# dtype: int64

# %%
print(df.head())
print(df.columns)
# Out:
#                     Contents        Date                Release Number  \
# 0                       Fury  26/11/2014  The Movie Leak (1st release)
# 1                      Annie  26/11/2014  The Movie Leak (1st release)
# 2                Still Alice  26/11/2014  The Movie Leak (1st release)
# 3                 Mr. Turner  26/11/2014  The Movie Leak (1st release)
# 4  To Write Love on Her Arms  26/11/2014  The Movie Leak (1st release)
#
#   Main Contents of Leak Approximate Size (Mb) Files  \
# 0      Unreleased Movie                  2000     1
# 1      Unreleased Movie                  2000     1
# 2      Unreleased Movie                  2000     1
# 3      Unreleased Movie                  2000     1
# 4      Unreleased Movie                  2000     1
#
#                                               Source
# 0  https://www.riskbasedsecurity.com/2014/12/a-br...
# 1  https://www.riskbasedsecurity.com/2014/12/a-br...
# 2  https://www.riskbasedsecurity.com/2014/12/a-br...
# 3  https://www.riskbasedsecurity.com/2014/12/a-br...
# 4  https://www.riskbasedsecurity.com/2014/12/a-br...
# Index(['Contents', 'Date', 'Release Number', 'Main Contents of Leak',
#        'Approximate Size (Mb)', 'Files', 'Source'],
#       dtype='str')

# %%
print(dir())
# Out:
# ['In', 'KMeans', 'Out', 'PCA', 'TfidfVectorizer', 'WordNetLemmatizer', '_', '_1', '_2', '_3', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__session__', '__spec__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i2', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', 'clean_text', 'df', 'exit', 'get_ipython', 'i', 'k', 'kmeans', 'lemmatizer', 'nltk', 'np', 'open', 'pd', 'plt', 'quit', 're', 'stop_words', 'stopwords']

# %%
print(df.columns)
# Out:
# Index(['Contents', 'Date', 'Release Number', 'Main Contents of Leak',
#        'Approximate Size (Mb)', 'Files', 'Source'],
#       dtype='str')

# %%
df.to_csv("clustered_leaked_files.csv", index=False)
