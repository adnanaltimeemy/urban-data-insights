# %%
# Step 1: Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_text
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Step 2: Load the dataset
df = pd.read_csv('CPD Employees active-duty-only.csv')

# Quick look at the dataset
df.head()
# Out:
#       LAST_NME FIRST_NME EMPLOYEE_POSITION  CPD_UNIT_ASSIGNED_NO  \
# 0  ABDELMAJEID      AZIZ    POLICE OFFICER                   1.0
# 1        ABRON     FLOYD    POLICE OFFICER                   1.0
# 2      ALVAREZ   ARMANDO    POLICE OFFICER                   1.0
# 3     ANDERSON     COREY    POLICE OFFICER                   1.0
# 4   ANDONAEGUI    ARTURO    POLICE OFFICER                   1.0
#
#     UNITASGDESC   AGE APPOINTED_DATE SEX_CODE_CD                    RACE  \
# 0  DISTRICT 001  31.0      28-Apr-08           M  ASIAN/PACIFIC ISLANDER
# 1  DISTRICT 001  42.0      29-Jun-98           M                   BLACK
# 2  DISTRICT 001  39.0      30-Apr-07           M                HISPANIC
# 3  DISTRICT 001  47.0      26-Mar-01           M                   BLACK
# 4  DISTRICT 001  48.0       4-Oct-99           M                   WHITE
#
#    STAR_NO SWORN_OFFICER_I
# 0  14008.0               Y
# 1  12861.0               Y
# 2   7861.0               Y
# 3   6023.0               Y
# 4  13718.0               Y

# %%
# Step 3: Explore the dataset
print(df.info())
print(df.describe())
print(df.isnull().sum())  # Check for missing values
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13530 entries, 0 to 13529
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   LAST_NME              12876 non-null  str
#  1   FIRST_NME             12875 non-null  str
#  2   EMPLOYEE_POSITION     13527 non-null  str
#  3   CPD_UNIT_ASSIGNED_NO  13527 non-null  float64
#  4   UNITASGDESC           13527 non-null  str
#  5   AGE                   13527 non-null  float64
#  6   APPOINTED_DATE        13527 non-null  str
#  7   SEX_CODE_CD           13527 non-null  str
#  8   RACE                  13527 non-null  str
#  9   STAR_NO               11819 non-null  float64
#  10  SWORN_OFFICER_I       13527 non-null  str
# dtypes: float64(3), str(8)
# memory usage: 1.9 MB
# None
#        CPD_UNIT_ASSIGNED_NO           AGE       STAR_NO
# count          13527.000000  13527.000000  11819.000000
# mean              96.288978     43.940046  12701.934174
# std              180.021863      9.420290   9512.611288
# min                1.000000     18.000000      3.000000
# 25%                8.000000     37.000000   5966.500000
# 50%               16.000000     45.000000  12310.000000
# 75%               50.000000     50.000000  17475.000000
# max              704.000000     87.000000  50800.000000
# LAST_NME                 654
# FIRST_NME                655
# EMPLOYEE_POSITION          3
# CPD_UNIT_ASSIGNED_NO       3
# UNITASGDESC                3
# AGE                        3
# APPOINTED_DATE             3
# SEX_CODE_CD                3
# RACE                       3
# STAR_NO                 1711
# SWORN_OFFICER_I            3
# dtype: int64

# %%
categorical_columns = df.select_dtypes(include=['object', 'string']).columns

# %%
target_col = 'Status'

if target_col in df.columns:
    X = df.drop(target_col, axis=1)
    y = df[target_col]
else:
    print(f"Column '{target_col}' not found. Available columns: {df.columns}")
# Out:
# Column 'Status' not found. Available columns: Index(['LAST_NME', 'FIRST_NME', 'EMPLOYEE_POSITION', 'CPD_UNIT_ASSIGNED_NO',
#        'UNITASGDESC', 'AGE', 'APPOINTED_DATE', 'SEX_CODE_CD', 'RACE',
#        'STAR_NO', 'SWORN_OFFICER_I'],
#       dtype='str')

# %%
print(df.columns)
# Out:
# Index(['LAST_NME', 'FIRST_NME', 'EMPLOYEE_POSITION', 'CPD_UNIT_ASSIGNED_NO',
#        'UNITASGDESC', 'AGE', 'APPOINTED_DATE', 'SEX_CODE_CD', 'RACE',
#        'STAR_NO', 'SWORN_OFFICER_I'],
#       dtype='str')

# %%
target_col = "PUT_YOUR_REAL_TARGET_HERE"

if target_col not in df.columns:
    print("Available columns:", df.columns)
else:
    X = df.drop(target_col, axis=1)
    y = df[target_col]
# Out:
# Available columns: Index(['LAST_NME', 'FIRST_NME', 'EMPLOYEE_POSITION', 'CPD_UNIT_ASSIGNED_NO',
#        'UNITASGDESC', 'AGE', 'APPOINTED_DATE', 'SEX_CODE_CD', 'RACE',
#        'STAR_NO', 'SWORN_OFFICER_I'],
#       dtype='str')
