# %%
# Step 1: Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Step 2: Load the dataset
df = pd.read_csv("police_departments_data.csv")

# Quick look at the data
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   city_department_id  6 non-null      int64
#  1   city                6 non-null      str
#  2   address             6 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 403.0 bytes
#        city_department_id
# count            6.000000
# mean        353535.000000
# std         188972.406319
# min         101010.000000
# 25%         227272.500000
# 50%         353535.000000
# 75%         479797.500000
# max         606060.000000

# %%
print(df.isnull().sum())
df = df.dropna()
# Out:
# city_department_id    0
# city                  0
# address               0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['city_department_id', 'city', 'address'], dtype='str')
