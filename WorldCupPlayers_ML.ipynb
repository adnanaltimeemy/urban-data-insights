# %%
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Models
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# Evaluation
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("WorldCupPlayers.csv")

# View dataset
df.head()
# Out:
#    RoundID  MatchID Team Initials  ...       Player Name Position  Event
# 0      201     1096           FRA  ...       Alex THEPOT       GK    NaN
# 1      201     1096           MEX  ...   Oscar BONFIGLIO       GK    NaN
# 2      201     1096           FRA  ...  Marcel LANGILLER      NaN   G40'
# 3      201     1096           MEX  ...      Juan CARRENO      NaN   G70'
# 4      201     1096           FRA  ...   Ernest LIBERATI      NaN    NaN
#
# [5 rows x 9 columns]

# %%
df = df.dropna()  # or use fillna()

# %%
for col in df.columns:
    print(f"'{col}'")
# Out:
# 'RoundID'
# 'MatchID'
# 'Team Initials'
# 'Coach Name'
# 'Line-up'
# 'Shirt Number'
# 'Player Name'
# 'Position'
# 'Event'

# %%
print(df.head())
print(df.columns)
# Out:
#      RoundID  MatchID Team Initials  ...       Player Name Position      Event
# 35       201     1090           USA  ...        Tom FLORIE        C       G45'
# 74       201     1093           BRA  ...         PREGUINHO        C       G62'
# 113      201     1098           PER  ...   Placido GALINDO        C       R70'
# 415      201     1091           BRA  ...         PREGUINHO        C  G67' G83'
# 468      201     1089           PAR  ...  Luis VARGAS PENA        C       G40'
#
# [5 rows x 9 columns]
# Index(['RoundID', 'MatchID', 'Team Initials', 'Coach Name', 'Line-up',
#        'Shirt Number', 'Player Name', 'Position', 'Event'],
#       dtype='str')

# %%
X = df.iloc[:, :-1]  # all columns except last
y = df.iloc[:, -1]   # last column

# %%
print('y_test' in dir())
# Out:
# False

# %%
dir()
# Out:
# ['DecisionTreeClassifier',
#  'In',
#  'LabelEncoder',
#  'Out',
#  'RandomForestClassifier',
#  'X',
#  '_',
#  '_2',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__session__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'accuracy_score',
#  'classification_report',
#  'col',
#  'confusion_matrix',
#  'df',
#  'dt_model',
#  'exit',
#  'get_ipython',
#  'np',
#  'open',
#  'pd',
#  'plt',
#  'quit',
#  'sns',
#  'train_test_split',
#  'y']
