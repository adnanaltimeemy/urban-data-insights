# %%
# Install if needed
# !pip install pandas scikit-learn matplotlib seaborn

# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
# Out:
# Requirement already satisfied: pandas in ./miniconda3/envs/coding/lib/python3.12/site-packages (3.0.2)
# Requirement already satisfied: scikit-learn in ./miniconda3/envs/coding/lib/python3.12/site-packages (1.8.0)
# Requirement already satisfied: matplotlib in ./miniconda3/envs/coding/lib/python3.12/site-packages (3.10.8)
# Requirement already satisfied: seaborn in ./miniconda3/envs/coding/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.26.0 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.10.0 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# Load dataset
df = pd.read_csv("chess_games.csv")

# Preview
df.head()
# Out:
#    game_id  rated  ...  opening_response    opening_variation
# 0        1  False  ...               NaN   Exchange Variation
# 1        2   True  ...               NaN    Kennedy Variation
# 2        3   True  ...               NaN  Leonardis Variation
# 3        4   True  ...               NaN  Zukertort Variation
# 4        5   True  ...               NaN                  NaN
#
# [5 rows x 17 columns]

# %%
for col in ['moves', 'opening_name']:
    if col not in df.columns:
        df[col] = ""
    else:
        df[col] = df[col].fillna("")

# %%
if 'content' in df.columns:
    print(df['content'].head())
else:
    print("Column not found!")
# Out:
# Column not found!

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# Create a sample dataset
X, y = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=42)

# Elbow method
inertia = []
K_range = range(2, 10)

for k in K_range:
    km = KMeans(n_clusters=k, random_state=42)
    km.fit(X)
    inertia.append(km.inertia_)

plt.plot(K_range, inertia, marker='o')
plt.title("Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("Inertia")
plt.show()

# %%
df.head()
# Out:
#    game_id  rated  turns  ... opening_response    opening_variation opening_name
# 0        1  False     13  ...              NaN   Exchange Variation
# 1        2   True     16  ...              NaN    Kennedy Variation
# 2        3   True     61  ...              NaN  Leonardis Variation
# 3        4   True     61  ...              NaN  Zukertort Variation
# 4        5   True     95  ...              NaN                  NaN
#
# [5 rows x 18 columns]

# %%
print(df.shape)
print(X.shape)
# Out:
# (20058, 18)
# (300, 2)

# %%
df.head()
# Out:
#    game_id  rated  turns  ... opening_response    opening_variation opening_name
# 0        1  False     13  ...              NaN   Exchange Variation
# 1        2   True     16  ...              NaN    Kennedy Variation
# 2        3   True     61  ...              NaN  Leonardis Variation
# 3        4   True     61  ...              NaN  Zukertort Variation
# 4        5   True     95  ...              NaN                  NaN
#
# [5 rows x 18 columns]

# %%
print(df.columns)
# Out:
# Index(['game_id', 'rated', 'turns', 'victory_status', 'winner',
#        'time_increment', 'white_id', 'white_rating', 'black_id',
#        'black_rating', 'moves', 'opening_code', 'opening_moves',
#        'opening_fullname', 'opening_shortname', 'opening_response',
#        'opening_variation', 'opening_name'],
#       dtype='str')

# %%
print(df.columns.tolist())
# Out:
# ['game_id', 'rated', 'turns', 'victory_status', 'winner', 'time_increment', 'white_id', 'white_rating', 'black_id', 'black_rating', 'moves', 'opening_code', 'opening_moves', 'opening_fullname', 'opening_shortname', 'opening_response', 'opening_variation', 'opening_name']

# %%
print(type(df))
print(df.head())
# Out:
# <class 'pandas.DataFrame'>
#    game_id  rated  turns  ... opening_response    opening_variation opening_name
# 0        1  False     13  ...              NaN   Exchange Variation
# 1        2   True     16  ...              NaN    Kennedy Variation
# 2        3   True     61  ...              NaN  Leonardis Variation
# 3        4   True     61  ...              NaN  Zukertort Variation
# 4        5   True     95  ...              NaN                  NaN
#
# [5 rows x 18 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# Example corpus
corpus = [
    "This is the first document.",
    "This document is the second document.",
    "And this is the third one.",
    "Is this the first document?"
]

# Create the vectorizer
vectorizer = TfidfVectorizer()

# Fit and transform the corpus
X = vectorizer.fit_transform(corpus)  # <-- this builds the vocabulary
