# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Load dataset
df = pd.read_csv('fish_recipes_transactions.csv')
df.head()
# Out:
#   soak apricots;juice grated rind lemon;chopped fresh coriander;potato pepper salad french dressing serve;thick coley;butter;salt pepper;fresh mint sprigs garnish;;;;;;;;;;;
# 0  salt;sliced lemon;butter;fish steaks;milk;wate...
# 1  salt table;butter print sure;fish fillets flat...
# 2  fresh herb;white wine;lemon herb dijon glaze;f...
# 3  salt;vinegar;mustard;worcestershire sauce;pepp...
# 4  salt;vinegar;mustard;worcestershire sauce;pepp...

# %%
# Check columns and missing values
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                                                                                                       --------------  -----
#  0   soak apricots;juice grated rind lemon;chopped fresh coriander;potato pepper salad french dressing serve;thick coley;butter;salt pepper;fresh mint sprigs garnish;;;;;;;;;;;  45 non-null     str
# dtypes: str(1)
# memory usage: 6.2 KB
# None
#        soak apricots;juice grated rind lemon;chopped fresh coriander;potato pepper salad french dressing serve;thick coley;butter;salt pepper;fresh mint sprigs garnish;;;;;;;;;;;
# count                                                  45
# ...

# %%
print(df.head())
# Out:
#   soak apricots;juice grated rind lemon;chopped fresh coriander;potato pepper salad french dressing serve;thick coley;butter;salt pepper;fresh mint sprigs garnish;;;;;;;;;;;
# 0  salt;sliced lemon;butter;fish steaks;milk;wate...
# 1  salt table;butter print sure;fish fillets flat...
# 2  fresh herb;white wine;lemon herb dijon glaze;f...
# 3  salt;vinegar;mustard;worcestershire sauce;pepp...
# 4  salt;vinegar;mustard;worcestershire sauce;pepp...

# %%
print(df.columns)
# Out:
# Index(['soak apricots;juice grated rind lemon;chopped fresh coriander;potato pepper salad french dressing serve;thick coley;butter;salt pepper;fresh mint sprigs garnish;;;;;;;;;;;'], dtype='str')

# %%
df.columns = df.columns.str.strip()

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

X_num_raw = np.array([[1, 10], [2, 20], [3, 30]])
scaler = StandardScaler()
X_num = scaler.fit_transform(X_num_raw)  # This is a dense NumPy array

# %%
numeric_features = df.select_dtypes(include='number').columns
X_combined = df[numeric_features]

# %%
print(df.columns)
# Out:
# Index(['soak apricots;juice grated rind lemon;chopped fresh coriander;potato pepper salad french dressing serve;thick coley;butter;salt pepper;fresh mint sprigs garnish;;;;;;;;;;;'], dtype='str')
