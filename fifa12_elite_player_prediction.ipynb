# %%
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# ML Models
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# Evaluation
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Load your dataset
df = pd.read_csv("fifa-soccer-12-ultimate-team-data-player-database.csv")

# Preview data
df.head()
# Out:
#        id                     name   rating  ...  reflexes   speed  positioning
# 0    1001             Gábor Király       69  ...        74      35         66.0
# 1  100143             Frederik Boi       65  ...                            NaN
# 2  100264          Tomasz Szewczuk       57  ...                            NaN
# 3  100325   Steeve Joseph-Reinette       63  ...                            NaN
# 4  100326             Kamel Chafni       72  ...                            NaN
#
# [5 rows x 19 columns]

# %%
print(df.shape)
print(df.columns)
print(df.info())
print(df.describe())
# Out:
# (8847, 19)
# Index(['id', ' name', ' rating', ' position', ' height', ' foot', ' rare',
#        ' pace', ' shooting', ' passing', ' dribbling', ' defending',
#        ' heading', ' diving', ' handling', ' kicking', ' reflexes', ' speed',
#        ' positioning'],
#       dtype='str')
# <class 'pandas.DataFrame'>
# RangeIndex: 8847 entries, 0 to 8846
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            8847 non-null   int64
#  1    name         8847 non-null   str
#  2    rating       8847 non-null   int64
#  3    position     8847 non-null   str
#  4    height       8847 non-null   int64
#  5    foot         8847 non-null   str
#  6    rare         8847 non-null   int64
#  7    pace         8847 non-null   str
#  8    shooting     8847 non-null   str
#  9    passing      8847 non-null   str
#  10   dribbling    8847 non-null   str
#  11   defending    8847 non-null   str
# ...

# %%
# Drop unnecessary columns if they exist
drop_cols = ['player_id', 'name', 'club', 'nationality']
df = df.drop(columns=[col for col in drop_cols if col in df.columns], errors='ignore')

# Handle missing values
df = df.fillna(df.mean(numeric_only=True))

# Convert categorical columns (if any)
df = pd.get_dummies(df, drop_first=True)

# %%
print(df.columns)
# Out:
# Index(['id', ' rating', ' height', ' rare', ' positioning',
#        ' name_ A.J. Soares', ' name_ Aaron', ' name_ Aaron Brown',
#        ' name_ Aaron Cresswell', ' name_ Aaron Doran',
#        ...
#        ' speed_ 62', ' speed_ 63', ' speed_ 64', ' speed_ 65', ' speed_ 66',
#        ' speed_ 67', ' speed_ 68', ' speed_ 69', ' speed_ 71', ' speed_ 73'],
#       dtype='str', length=9365)

# %%
import pandas as pd

df = pd.read_csv("fifa-soccer-12-ultimate-team-data-player-database.csv")

X = df.iloc[:, :-1]   # all columns except last
y = df.iloc[:, -1]    # last column

# %%
print(X.dtypes)
# Out:
# id            int64
#  name           str
#  rating       int64
#  position       str
#  height       int64
#  foot           str
#  rare         int64
#  pace           str
#  shooting       str
#  passing        str
#  dribbling      str
#  defending      str
#  heading        str
#  diving         str
#  handling       str
#  kicking        str
#  reflexes       str
#  speed          str
# dtype: object

# %%
print(X_train.dtypes)
# Out:
# id            int64
#  name           str
#  rating       int64
#  position       str
#  height       int64
#  foot           str
#  rare         int64
#  pace           str
#  shooting       str
#  passing        str
#  dribbling      str
#  defending      str
#  heading        str
#  diving         str
#  handling       str
#  kicking        str
#  reflexes       str
#  speed          str
# dtype: object
